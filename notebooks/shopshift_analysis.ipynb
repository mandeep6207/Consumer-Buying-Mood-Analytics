# %% [markdown]
# # ShopShift AI
# Consumer Buying Mood Analytics System
#
# This notebook runs the complete analytics pipeline, creates behavioral features, trains the mood models, and exports the project artifacts.

# %% [markdown]
# ## Analysis Workflow
#
# 1. Generate a realistic synthetic shopping dataset.
#
# 2. Clean and standardize the raw inputs.
#
# 3. Engineer behavioral signals such as engagement, conversion probability, and discount dependency.
#
# 4. Train and compare Logistic Regression, Random Forest, and XGBoost.
#
# 5. Export the reports, charts, and final model artifact.

# %% [markdown]
# ## Behavioral Feature Engineering
#
# The pipeline emphasizes signals that are useful for consumer mood inference:
#
# - `engagement_score` to capture browsing depth and attention.
#
# - `shopping_intensity` to combine browsing, cart, click, and spend behavior.
#
# - `conversion_probability` to estimate purchase intent from the behavioral profile.
#
# - `discount_dependency` to expose price sensitivity and promotion reliance.

# %%
from src.shopshift_ai.pipeline import main
main()

# %% [markdown]
# ## Reading the Results
#
# After the pipeline runs, review `reports/model_metrics.json` for the comparison summary and `metrics/classification_report.txt` for class-level performance. The visuals in `visuals/` provide the behavioral evidence behind the model scores.

# %% [markdown]
# ## Expected Outputs
# The execution generates the dataset, charts, trained model, metrics, and project report.
